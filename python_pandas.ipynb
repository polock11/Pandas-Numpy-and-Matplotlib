# %% [markdown]
# #Panndas Library
#  Useful for data preprossing and analysis

# %%
import pandas as pd

#importing boston data from sklearn
from sklearn.datasets import load_boston

# %%
diabetes_data = pd.read_csv('/content/diabetes.csv')
diabetes_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
boston_data = load_boston()
print(boston_data)
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]]), 'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
# ...

# %%
# creating a data frame
import numpy as np

boston_df = pd.DataFrame(boston_data.data, columns = boston_data.feature_names)
# Out:
#             CRIM       ZN      INDUS  ...    PTRATIO           B      LSTAT
# AGE                                   ...
# 2.9     0.127440  0.00000   6.910000  ...  17.900000  385.410000   4.840000
# 6.0     0.078960  0.00000  12.830000  ...  18.700000  394.920000   6.780000
# 6.2     0.195390  0.00000  10.810000  ...  19.200000  377.170000   7.540000
# 6.5     0.159360  0.00000   6.910000  ...  17.900000  394.460000   7.440000
# 6.6     0.114880  0.00000   8.860000  ...  18.550000  383.550000   6.265000
# ...          ...      ...        ...  ...        ...         ...        ...
# 98.8    4.742852  0.00000  21.457500  ...  20.425000  393.972500  17.955000
# 98.9    5.387940  0.00000  19.363333  ...  20.533333  395.013333  17.790000
# 99.1   15.874400  0.00000  18.100000  ...  20.200000  396.900000  21.080000
# 99.3    8.248090  0.00000  18.100000  ...  20.200000  375.870000  16.740000
# 100.0  15.054894  1.22093  16.896047  ...  18.876744  300.006279  21.234651
#
# ...

# %% [markdown]
# #Load Exel Data

# %%
e_data = pd.read_excel('/content/uCanada.xlsx')
e_data.head(7)
# Out:
#                                       Name  ...  Tuition Fee
# 0                    University of Guelph   ...          NaN
# 1                 University of Lethbridge  ...          NaN
# 2                   University of Manitoba  ...          NaN
# 3  University of Northern British Columbia  ...          NaN
# 4                     University of Regina  ...          NaN
# 5                    University of Winsdor  ...          NaN
# 6                   University of Winnipeg  ...  $28000 (2Y)
#
# [7 rows x 8 columns]

# %%
# data frame with randdom vals

random_df = pd.DataFrame(np.random.rand(50,12))
random_df.head()
# Out:
#          0         1         2   ...        9         10        11
# 0  0.672509  0.003413  0.476605  ...  0.477042  0.324009  0.298473
# 1  0.004111  0.626116  0.947883  ...  0.591360  0.187576  0.863089
# 2  0.523774  0.745953  0.910344  ...  0.995754  0.450565  0.255804
# 3  0.147827  0.394576  0.584191  ...  0.013502  0.468932  0.506477
# 4  0.926125  0.317934  0.914435  ...  0.466509  0.723027  0.515941
#
# [5 rows x 12 columns]

# %%
# inspection on a df

boston_df.tail()
boston_df.info()
e_data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
# dtypes: float64(13)
# memory usage: 51.5 KB
# Name              0
# Province          0
# City              0
# Course            7
# Apply Start       7
# Apply End         7
# Applicatio fee    7
# Tuition Fee       7
# dtype: int64

# %%
#counting data based on lables
diabetes_data.value_counts('Age')
# Out:
# Age
# 22    72
# 21    63
# 25    48
# 24    46
# 23    38
# 28    35
# 26    33
# 27    32
# 29    29
# 31    24
# 41    22
# 30    21
# 37    19
# 42    18
# 33    17
# 38    16
# 36    16
# 32    16
# 45    15
# 34    14
# 40    13
# 43    13
# 46    13
# 39    12
# 35    10
# 52     8
# 44     8
# 50     8
# 51     8
# 58     7
# 54     6
# 47     6
# 53     5
# 60     5
# 49     5
# 57     5
# 48     5
# 66     4
# 62     4
# 63     4
# 55     4
# 59     3
# 56     3
# 65     3
# 67     3
# 61     2
# 69     2
# 64     1
# 68     1
# 70     1
# 72     1
# 81     1
# dtype: int64

# %%
# statitical measures

boston_df.count()
boston_df.mean()
boston_df.std()
boston_df.min()
boston_df.max()
boston_df.describe()
# Out:
# CRIM        88.9762
# ZN         100.0000
# INDUS       27.7400
# CHAS         1.0000
# NOX          0.8710
# RM           8.7800
# AGE        100.0000
# DIS         12.1265
# RAD         24.0000
# TAX        711.0000
# PTRATIO     22.0000
# B          396.9000
# LSTAT       37.9700
# dtype: float64

# %%
# Manipulatind df

# adding column
boston_df['Price'] = boston_data.target
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  Price
# 0  0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98   24.0
# 1  0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14   21.6
# 2  0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03   34.7
# 3  0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94   33.4
# 4  0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33   36.2
#
# [5 rows x 14 columns]

# %%
boston_df.drop(index = 0, axis = 0)
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  Price
# 1    0.02731  0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14   21.6
# 2    0.02729  0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03   34.7
# 3    0.03237  0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94   33.4
# 4    0.06905  0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33   36.2
# 5    0.02985  0.0   2.18   0.0  0.458  ...  222.0     18.7  394.12   5.21   28.7
# ..       ...  ...    ...   ...    ...  ...    ...      ...     ...    ...    ...
# 501  0.06263  0.0  11.93   0.0  0.573  ...  273.0     21.0  391.99   9.67   22.4
# 502  0.04527  0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   9.08   20.6
# 503  0.06076  0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   5.64   23.9
# 504  0.10959  0.0  11.93   0.0  0.573  ...  273.0     21.0  393.45   6.48   22.0
# 505  0.04741  0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   7.88   11.9
#
# ...

# %%
boston_df.drop(columns = 'ZN', axis = 1)
# Out:
#         CRIM  INDUS  CHAS    NOX     RM  ...    TAX  PTRATIO       B  LSTAT  Price
# 0    0.00632   2.31   0.0  0.538  6.575  ...  296.0     15.3  396.90   4.98   24.0
# 1    0.02731   7.07   0.0  0.469  6.421  ...  242.0     17.8  396.90   9.14   21.6
# 2    0.02729   7.07   0.0  0.469  7.185  ...  242.0     17.8  392.83   4.03   34.7
# 3    0.03237   2.18   0.0  0.458  6.998  ...  222.0     18.7  394.63   2.94   33.4
# 4    0.06905   2.18   0.0  0.458  7.147  ...  222.0     18.7  396.90   5.33   36.2
# ..       ...    ...   ...    ...    ...  ...    ...      ...     ...    ...    ...
# 501  0.06263  11.93   0.0  0.573  6.593  ...  273.0     21.0  391.99   9.67   22.4
# 502  0.04527  11.93   0.0  0.573  6.120  ...  273.0     21.0  396.90   9.08   20.6
# 503  0.06076  11.93   0.0  0.573  6.976  ...  273.0     21.0  396.90   5.64   23.9
# 504  0.10959  11.93   0.0  0.573  6.794  ...  273.0     21.0  393.45   6.48   22.0
# ...

# %%
boston_df.iloc[2]
# Out:
# CRIM         0.02729
# ZN           0.00000
# INDUS        7.07000
# CHAS         0.00000
# NOX          0.46900
# RM           7.18500
# AGE         61.10000
# DIS          4.96710
# RAD          2.00000
# TAX        242.00000
# PTRATIO     17.80000
# B          392.83000
# LSTAT        4.03000
# Price       34.70000
# Name: 2, dtype: float64
