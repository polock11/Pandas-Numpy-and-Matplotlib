# %% [markdown]
# lambda x : x + 1

# %%
import math as mat

# %%
l = [1,2,3,4,5]
evens = list(filter(lambda x: (x%2==0),l))
print(evens)

f_x = lambda x: x**3+ mat.sqrt(64)
f_x(3)
# Out:
# [2, 4]
# 35.0
